# %%
#!pip install librosa
#!conda install -n DataEngineering -c conda-forge sounddevice
#!pip install resampy
#!pip install keras
#!pip install resampy

# %%
import librosa 
import pandas as pd 
import numpy as np
import random 
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from keras.utils import to_categorical 
from keras.models import Sequential
from keras.layers import Dense
from IPython.display import Audio

# %%
audiofiles = pd.read_csv('/Users/jamesjr/Documents/audio_data/UrbanSound8K/metadata/UrbanSound8K.csv')
audiofiles.head()
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
audio_path = r'/Users/jamesjr/Documents/audio_data/UrbanSound8K/audio/fold'

# %%
audiofiles['class'].unique()
# Out:
# array(['dog_bark', 'children_playing', 'car_horn', 'air_conditioner',
#        'street_music', 'gun_shot', 'siren', 'engine_idling', 'jackhammer',
#        'drilling'], dtype=object)

# %%
idx = list(np.where(audiofiles['class']=='gun_shot')[0])[0]

arr = np.array(audiofiles['slice_file_name'])
fold = np.array(audiofiles['fold'])
cla = np.array(audiofiles['class'])

original_audio, sample_rate = librosa.load(audio_path + str(fold[idx]) + '/' + str(arr[idx]))

Audio(data= original_audio, rate = sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import matplotlib.pyplot as plt 
fig, ax = plt.subplots(nrows=1, sharex=True)
librosa.display.waveshow(original_audio,sr=sample_rate,ax=ax)
ax.set(title='Gun Shot Waveform')
ax.set_ylabel('amplitude')
ax.set_xlabel('Time [secs]')
# Out:
# Text(0.5, 23.52222222222222, 'Time [secs]')

# %%
D = librosa.amplitude_to_db(np.abs(librosa.stft(original_audio)),ref = np.max)
D.shape

plt.plot(D[100])

# %%
librosa.display.specshow(D,y_axis='linear',x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title(cla[idx])
# Out:
# Text(0.5, 1.0, 'gun_shot')

# %%
rng = np.random.default_rng()
sample = rng.integers(0,audiofiles.shape[0], size = 5)

for i in sample: 
    path = audio_path + str(fold[i]) + '/' + str(arr[i])
    data, sampling_rate = librosa.load(path)
    plt.figure(figsize =(10,5))
    D = librosa.amplitude_to_db(np.abs(librosa.stft(data)),ref=np.max)
    plt.subplot(4,2,1)
    librosa.display.specshow(D,y_axis='linear')
    plt.colorbar(format='%+2.0f dB')
    plt.title(cla[i])

# %%
path = audio_path + str(fold[idx]) + '/' + str(arr[idx])
data, sampling_rate = librosa.load(path)
melspec = librosa.feature.melspectrogram(y=data,sr=sampling_rate)
print(melspec.shape)
print(cla[idx])

Audio(data=data,rate = sampling_rate)

import matplotlib.pyplot as plt
fig, ax = plt.subplots()
S_dB = librosa.power_to_db(melspec, ref=np.max)
img = librosa.display.specshow(S_dB, x_axis='time',
                         y_axis='mel', sr=sampling_rate,
                         fmax=8000, ax=ax)
fig.colorbar(img, ax=ax, format='%+2.0f dB')
ax.set(title='Mel-frequency spectrogram')
# Out:
# (128, 113)
# gun_shot
# [Text(0.5, 1.0, 'Mel-frequency spectrogram')]

# %%
feature = []
label = []

for i in range(len(audiofiles)):
    filename = audio_path + str(audiofiles['fold'][i]) + '/' + str(audiofiles['slice_file_name'][i])
    X, sample_rate = librosa.load(filename, res_type='kaiser_fast')
    mels = np.mean(librosa.feature.melspectrogram(y=X,sr=sample_rate).T,axis=0)
    feature.append(mels)
    label.append(audiofiles['classID'][i])
# Out:
# /Users/jamesjr/anaconda3/envs/DataEngineering/lib/python3.10/site-packages/librosa/core/spectrum.py:256: UserWarning: n_fft=2048 is too large for input signal of length=1323
#   warnings.warn(
# /Users/jamesjr/anaconda3/envs/DataEngineering/lib/python3.10/site-packages/librosa/core/spectrum.py:256: UserWarning: n_fft=2048 is too large for input signal of length=1103
#   warnings.warn(
# /Users/jamesjr/anaconda3/envs/DataEngineering/lib/python3.10/site-packages/librosa/core/spectrum.py:256: UserWarning: n_fft=2048 is too large for input signal of length=1523
#   warnings.warn(

# %%
classids = audiofiles['classID'].unique()
classes = audiofiles['class'].unique()

# %%
temp = np.array([feature,label],dtype='object')
data = temp.transpose()

# %%
X_ = data[:,0]
Y = data[:,1]

print(X_.shape,Y.shape)
# Out:
# (8732,) (8732,)

# %%
X = np.empty([8732,128])

for i in range(8732):
    X[i] = (X_[i])

# %%
Y = to_categorical(Y)

# %%
print(X.shape)
(Y.shape)
# Out:
# (8732, 128)
# (8732, 10)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,random_state=123,test_size = 0.2)
print('Number of Train Samples',X_train.shape[0])
print('Number of test samples',X_test.shape[0])
# Out:
# Number of Train Samples 6985
# Number of test samples 1747

# %%
model = Sequential(
        [
            Dense(1000,activation='relu',input_shape=(128,)),
            Dense(750,activation='relu'),
            Dense(500,activation='relu'),
            Dense(250,activation='relu'),
            Dense(100,activation='relu'),
            Dense(50,activation='relu'),
            Dense(10,activation='softmax'),
            
        ]
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1000)              129000
#
#  dense_1 (Dense)             (None, 750)               750750
#
#  dense_2 (Dense)             (None, 500)               375500
#
#  dense_3 (Dense)             (None, 250)               125250
#
#  dense_4 (Dense)             (None, 100)               25100
#
#  dense_5 (Dense)             (None, 50)                5050
#
#  dense_6 (Dense)             (None, 10)                510
#
# =================================================================
# Total params: 1411160 (5.38 MB)
# Trainable params: 1411160 (5.38 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(X_train,Y_train,epochs=90,batch_size=50,validation_data=[X_test,Y_test])
# Out:
# Epoch 1/90
# 140/140 [==============================] - 1s 4ms/step - loss: 2.1982 - accuracy: 0.2991 - val_loss: 1.9191 - val_accuracy: 0.3881
# Epoch 2/90
# 140/140 [==============================] - 1s 4ms/step - loss: 1.8085 - accuracy: 0.4082 - val_loss: 1.7091 - val_accuracy: 0.4430
# Epoch 3/90
# 140/140 [==============================] - 1s 4ms/step - loss: 1.4897 - accuracy: 0.5120 - val_loss: 1.4593 - val_accuracy: 0.5392
# Epoch 4/90
# 140/140 [==============================] - 1s 4ms/step - loss: 1.2783 - accuracy: 0.5931 - val_loss: 1.4170 - val_accuracy: 0.5272
# Epoch 5/90
# 140/140 [==============================] - 1s 4ms/step - loss: 1.0764 - accuracy: 0.6626 - val_loss: 1.1111 - val_accuracy: 0.6583
# Epoch 6/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.9019 - accuracy: 0.7117 - val_loss: 0.9828 - val_accuracy: 0.7064
# Epoch 7/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.8578 - accuracy: 0.7303 - val_loss: 1.0318 - val_accuracy: 0.6961
# Epoch 8/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.7265 - accuracy: 0.7765 - val_loss: 1.0325 - val_accuracy: 0.7029
# Epoch 9/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.6449 - accuracy: 0.7979 - val_loss: 1.1219 - val_accuracy: 0.6909
# Epoch 10/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.6060 - accuracy: 0.8089 - val_loss: 0.9471 - val_accuracy: 0.7453
# Epoch 11/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.5159 - accuracy: 0.8359 - val_loss: 1.0446 - val_accuracy: 0.7396
# Epoch 12/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.5401 - accuracy: 0.8348 - val_loss: 0.9905 - val_accuracy: 0.7630
# Epoch 13/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.4940 - accuracy: 0.8528 - val_loss: 0.8568 - val_accuracy: 0.7630
# Epoch 14/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.3967 - accuracy: 0.8747 - val_loss: 1.0955 - val_accuracy: 0.7481
# Epoch 15/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.4626 - accuracy: 0.8641 - val_loss: 0.8387 - val_accuracy: 0.7905
# Epoch 16/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.3580 - accuracy: 0.8859 - val_loss: 0.8820 - val_accuracy: 0.7785
# Epoch 17/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.3159 - accuracy: 0.8991 - val_loss: 0.9214 - val_accuracy: 0.7922
# Epoch 18/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.2782 - accuracy: 0.9107 - val_loss: 0.8965 - val_accuracy: 0.7997
# Epoch 19/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.3260 - accuracy: 0.9057 - val_loss: 0.8533 - val_accuracy: 0.7790
# Epoch 20/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.3279 - accuracy: 0.8972 - val_loss: 1.1012 - val_accuracy: 0.7894
# Epoch 21/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.2920 - accuracy: 0.9049 - val_loss: 0.9842 - val_accuracy: 0.8042
# Epoch 22/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.2366 - accuracy: 0.9256 - val_loss: 0.8283 - val_accuracy: 0.8031
# Epoch 23/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1909 - accuracy: 0.9374 - val_loss: 1.1679 - val_accuracy: 0.8054
# Epoch 24/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.2254 - accuracy: 0.9284 - val_loss: 1.0825 - val_accuracy: 0.8065
# Epoch 25/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1833 - accuracy: 0.9394 - val_loss: 0.9292 - val_accuracy: 0.8094
# Epoch 26/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1748 - accuracy: 0.9443 - val_loss: 1.1303 - val_accuracy: 0.8208
# Epoch 27/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1975 - accuracy: 0.9359 - val_loss: 1.0866 - val_accuracy: 0.7968
# Epoch 28/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.2113 - accuracy: 0.9366 - val_loss: 0.9388 - val_accuracy: 0.8105
# Epoch 29/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1992 - accuracy: 0.9382 - val_loss: 0.9042 - val_accuracy: 0.8294
# Epoch 30/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1850 - accuracy: 0.9417 - val_loss: 0.9857 - val_accuracy: 0.8117
# Epoch 31/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1844 - accuracy: 0.9380 - val_loss: 1.0891 - val_accuracy: 0.8031
# Epoch 32/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1928 - accuracy: 0.9446 - val_loss: 1.1089 - val_accuracy: 0.8042
# Epoch 33/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1897 - accuracy: 0.9469 - val_loss: 1.5433 - val_accuracy: 0.8197
# Epoch 34/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1662 - accuracy: 0.9522 - val_loss: 1.0519 - val_accuracy: 0.8334
# Epoch 35/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1227 - accuracy: 0.9579 - val_loss: 1.1690 - val_accuracy: 0.8386
# Epoch 36/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1108 - accuracy: 0.9658 - val_loss: 1.2908 - val_accuracy: 0.8237
# Epoch 37/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1325 - accuracy: 0.9592 - val_loss: 0.9408 - val_accuracy: 0.8271
# Epoch 38/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1292 - accuracy: 0.9575 - val_loss: 1.2620 - val_accuracy: 0.8134
# Epoch 39/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.2396 - accuracy: 0.9446 - val_loss: 1.2482 - val_accuracy: 0.8140
# Epoch 40/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.2264 - accuracy: 0.9372 - val_loss: 1.0804 - val_accuracy: 0.8128
# Epoch 41/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1893 - accuracy: 0.9532 - val_loss: 1.0945 - val_accuracy: 0.8157
# Epoch 42/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1840 - accuracy: 0.9503 - val_loss: 0.9953 - val_accuracy: 0.8088
# Epoch 43/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1354 - accuracy: 0.9540 - val_loss: 1.0146 - val_accuracy: 0.8226
# Epoch 44/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1485 - accuracy: 0.9611 - val_loss: 0.9843 - val_accuracy: 0.8243
# Epoch 45/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1458 - accuracy: 0.9572 - val_loss: 1.2802 - val_accuracy: 0.8271
# Epoch 46/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1113 - accuracy: 0.9668 - val_loss: 0.9897 - val_accuracy: 0.8323
# Epoch 47/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1879 - accuracy: 0.9455 - val_loss: 1.1388 - val_accuracy: 0.8140
# Epoch 48/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1061 - accuracy: 0.9672 - val_loss: 1.3010 - val_accuracy: 0.8248
# Epoch 49/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.0834 - accuracy: 0.9711 - val_loss: 1.2343 - val_accuracy: 0.8254
# Epoch 50/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1056 - accuracy: 0.9676 - val_loss: 1.0425 - val_accuracy: 0.8369
# Epoch 51/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.0847 - accuracy: 0.9727 - val_loss: 1.0348 - val_accuracy: 0.8323
# Epoch 52/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.0763 - accuracy: 0.9765 - val_loss: 1.2289 - val_accuracy: 0.8380
# Epoch 53/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.0589 - accuracy: 0.9787 - val_loss: 1.2286 - val_accuracy: 0.8403
# Epoch 54/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.0570 - accuracy: 0.9798 - val_loss: 1.1310 - val_accuracy: 0.8357
# Epoch 55/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1168 - accuracy: 0.9671 - val_loss: 1.2981 - val_accuracy: 0.8231
# Epoch 56/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.2070 - accuracy: 0.9452 - val_loss: 0.9732 - val_accuracy: 0.8243
# Epoch 57/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1477 - accuracy: 0.9582 - val_loss: 1.1468 - val_accuracy: 0.8277
# Epoch 58/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1060 - accuracy: 0.9682 - val_loss: 1.2187 - val_accuracy: 0.8277
# Epoch 59/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1127 - accuracy: 0.9649 - val_loss: 1.0869 - val_accuracy: 0.8271
# Epoch 60/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.0651 - accuracy: 0.9774 - val_loss: 1.2558 - val_accuracy: 0.8414
# Epoch 61/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.0829 - accuracy: 0.9742 - val_loss: 1.1278 - val_accuracy: 0.8397
# Epoch 62/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.0798 - accuracy: 0.9764 - val_loss: 1.2092 - val_accuracy: 0.8334
# Epoch 63/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.0999 - accuracy: 0.9714 - val_loss: 1.3334 - val_accuracy: 0.8088
# Epoch 64/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1376 - accuracy: 0.9586 - val_loss: 1.1091 - val_accuracy: 0.8340
# Epoch 65/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1400 - accuracy: 0.9619 - val_loss: 1.2598 - val_accuracy: 0.8237
# Epoch 66/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1574 - accuracy: 0.9585 - val_loss: 1.4893 - val_accuracy: 0.8128
# Epoch 67/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1769 - accuracy: 0.9542 - val_loss: 1.1943 - val_accuracy: 0.8237
# Epoch 68/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1170 - accuracy: 0.9654 - val_loss: 1.2966 - val_accuracy: 0.8248
# Epoch 69/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1917 - accuracy: 0.9656 - val_loss: 1.1838 - val_accuracy: 0.8203
# Epoch 70/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1435 - accuracy: 0.9685 - val_loss: 1.1332 - val_accuracy: 0.8466
# Epoch 71/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.0751 - accuracy: 0.9778 - val_loss: 1.3040 - val_accuracy: 0.8363
# Epoch 72/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.0540 - accuracy: 0.9814 - val_loss: 1.4628 - val_accuracy: 0.8363
# Epoch 73/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.0445 - accuracy: 0.9828 - val_loss: 1.6509 - val_accuracy: 0.8432
# Epoch 74/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.0637 - accuracy: 0.9785 - val_loss: 1.6651 - val_accuracy: 0.8346
# Epoch 75/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.0840 - accuracy: 0.9758 - val_loss: 1.2777 - val_accuracy: 0.8426
# Epoch 76/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1349 - accuracy: 0.9661 - val_loss: 1.1015 - val_accuracy: 0.8409
# Epoch 77/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.0947 - accuracy: 0.9714 - val_loss: 1.1034 - val_accuracy: 0.8208
# Epoch 78/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1059 - accuracy: 0.9671 - val_loss: 1.2083 - val_accuracy: 0.8403
# Epoch 79/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.0704 - accuracy: 0.9774 - val_loss: 1.2244 - val_accuracy: 0.8443
# Epoch 80/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.0938 - accuracy: 0.9738 - val_loss: 1.5794 - val_accuracy: 0.8397
# Epoch 81/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1874 - accuracy: 0.9599 - val_loss: 0.9956 - val_accuracy: 0.8128
# Epoch 82/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1662 - accuracy: 0.9553 - val_loss: 1.4628 - val_accuracy: 0.8197
# Epoch 83/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.2155 - accuracy: 0.9470 - val_loss: 1.1191 - val_accuracy: 0.8288
# Epoch 84/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1205 - accuracy: 0.9656 - val_loss: 1.5099 - val_accuracy: 0.8414
# Epoch 85/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1229 - accuracy: 0.9727 - val_loss: 1.4093 - val_accuracy: 0.8357
# Epoch 86/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.0843 - accuracy: 0.9738 - val_loss: 1.7791 - val_accuracy: 0.8443
# Epoch 87/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.0578 - accuracy: 0.9802 - val_loss: 1.1149 - val_accuracy: 0.8500
# Epoch 88/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1008 - accuracy: 0.9780 - val_loss: 1.1251 - val_accuracy: 0.8437
# Epoch 89/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.1001 - accuracy: 0.9768 - val_loss: 1.1991 - val_accuracy: 0.8374
# Epoch 90/90
# 140/140 [==============================] - 1s 4ms/step - loss: 0.0684 - accuracy: 0.9798 - val_loss: 2.2319 - val_accuracy: 0.8649

# %%
classes = audiofiles.groupby('classID')['class'].unique()
classes
# Out:
# classID
# 0     [air_conditioner]
# 1            [car_horn]
# 2    [children_playing]
# 3            [dog_bark]
# 4            [drilling]
# 5       [engine_idling]
# 6            [gun_shot]
# 7          [jackhammer]
# 8               [siren]
# 9        [street_music]
# Name: class, dtype: object

# %%
def prediction_parser(filename,model):
    feature = []
    label = []
    # Here kaiser_fast is a technique used for faster extraction
    audiodata, sample_rate = librosa.load(filename, res_type='kaiser_fast') 
    # We extract mfcc feature from data
    mels = np.mean(librosa.feature.melspectrogram(y=audiodata, sr=sample_rate).T,axis=0)        
    feature.append(mels)
    label.append(audiofiles["class"][audiofiles['slice_file_name']==filename.split('/',5)[5]].values[0])
    temp_preds = np.array([feature,label],dtype=object)
    data_preds = temp_preds.transpose()
    X_ = data_preds[:, 0]
    X = np.empty([1, 128])
    X[0] = (X_[0])
    Audio(data = original_audio, rate = sample_rate)
    classid = np.argmax(model.predict(X))
    print('Class predicted :',classes[classid][0],'\n\n','actual',label)
    return (Audio(data = audiodata, rate = sample_rate))

# %%
prediction_parser('/Users/jamesjr/Documents/audio_data/UrbanSound8K/audio/fold1/102305-6-0-0.wav',model)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 prediction_parser('/Users/jamesjr/Documents/audio_data/UrbanSound8K/audio/fold1/102305-6-0-0.wav',model)
#
# Cell In[28], line 9, in prediction_parser(filename, model)
#       7 mels = np.mean(librosa.feature.melspectrogram(y=audiodata, sr=sample_rate).T,axis=0)
#       8 feature.append(mels)
# ----> 9 label.append(audiofiles["class"][audiofiles['slice_file_name']==filename.split('/',5)[5]].values[0])
#      10 temp_preds = np.array([feature,label],dtype=object)
#      11 data_preds = temp_preds.transpose()
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
